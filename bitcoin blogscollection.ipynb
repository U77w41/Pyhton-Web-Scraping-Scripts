# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt

# %%
finviz_url = 'https://finviz.com/quote.ashx?t='
tickers = ['BTCS']

# %%
news_tables = {}
for ticker in tickers:
  url = finviz_url + ticker
  req = Request(url=url, headers={'user-agent': 'my-app'})
  response = urlopen(req)
  html = BeautifulSoup(response, features='html.parser')
  #print(html)
  news_table = html.find(id='news-table')
  news_tables[ticker] = news_table

# %%
crypto_data = news_tables['BTCM',]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-f87c6bb97cd7> in <module>
# ----> 1 crypto_data = news_tables['BTCM',]
#
# KeyError: ('BTCM',)

# %%
cryto_html = crypto_data.findAll('tr')

# %%
cryto_html

# %%
for index , row in enumerate(cryto_html):
  if row.a is not None:
    title = row.a.text
    timestamp = row.td.text
    print(timestamp + " " + title)
  # title = row.a.text
  # if type(title is not None:
  #   print(title)
# Out:
# Sep-09-22 08:41AM   BTCS Inc. and Force Family Office to Host a Closing Bell Webinar
# Aug-12-22 08:30AM   BTCS Reports Q2 2022 Results
# Jul-22-22 08:00AM   BTCS Inc. Interview to Air on Bloomberg U.S. on the RedChip Money Report(R)
# Jul-19-22 08:31AM   BTCS Inc. will participate in the Barrons virtual interview to discuss: Can the Digital Asset Industry Beat the Regulators?
# Jul-18-22 08:31AM   BTCS Inc. and Force Family Office to Host a Fireside Chat with Benchmark to discuss the state of blockchain and cryptocurrency sectors
# Jul-05-22 08:31AM   BTCS Announces Appointment of Skilled Industry Professional to Play Pivotal Role as Vice President of Investor Relations
# Jun-11-22 09:36AM   Is BTCS (NASDAQ:BTCS) In A Good Position To Deliver On Growth Plans?
# May-20-22 08:31AM   BTCS to Present at H. C. Wainwright Global Investment Conference on May 23-26, 2022
# May-17-22 08:31AM   BTCS Inc. and Force Family Office to Host Crypto 101: An Introduction to Decentralized Finance And The Technology That Powers It
# May-16-22 03:11PM   BTCS Shares Gain on Q1 Revenue Growth; Becomes First US Bitcoin Company To Declare Dividend
# 08:31AM   BTCS Reports Q1 2022 Results
# May-11-22 08:31AM   BTCS Adds Axie Infinity to its Blockchain Infrastructure Operations
# Apr-27-22 08:31AM   BTCS Adds Kava to its Blockchain Infrastructure Operations
# Apr-20-22 08:31AM   BTCS Adds Polygon to its Blockchain Infrastructure Operations
# Mar-16-22 09:01AM   BTCS to Present at Ladenburg Thalmann Virtual Special Crypto Expo on March 24th
# Mar-14-22 09:01AM   BTCS Reports Q4 2021 Results
# Mar-09-22 08:31AM   BTCS Adds Terra to its Growing Blockchain Infrastructure Operations
# Mar-02-22 08:31AM   BTCS Set to Offer a Dividend Payable in Bitcoin in Two Weeks
# Mar-01-22 09:00AM   BTCS Adds Polkadot to its Growing Blockchain Infrastructure Operations
# Feb-22-22 08:31AM   BTCS Prepares for Accelerated Growth with Appointment of Experienced Crypto Developer as CTO
# Feb-16-22 09:00AM   Solana Added to BTCS Blockchain Infrastructure
  for row in news_table.findAll('tr'):
    if row.a is not None:
      title = row.a.text
      date_data = row.td.text.split(' ')
      if len(date_data) == 1:
        time = date_data[0]
      else:
        date = date_data[0]
        time = date_data[1]
      parsed_data.append([ticker, date, time, title])

df = pd.DataFrame(parsed_data, columns=['ticker', 'date', 'time', 'title'])

# %%
df
# Out:
#    ticker       date       time  \
# 0    BTCS  Sep-09-22  08:41AM
# 1    BTCS  Aug-12-22  08:30AM
# 2    BTCS  Jul-22-22  08:00AM
# 3    BTCS  Jul-19-22  08:31AM
# 4    BTCS  Jul-18-22  08:31AM
# 5    BTCS  Jul-05-22  08:31AM
# 6    BTCS  Jun-11-22  09:36AM
# 7    BTCS  May-20-22  08:31AM
# 8    BTCS  May-17-22  08:31AM
# 9    BTCS  May-16-22  03:11PM
# 10   BTCS  May-16-22  08:31AM
# 11   BTCS  May-11-22  08:31AM
# 12   BTCS  Apr-27-22  08:31AM
# 13   BTCS  Apr-20-22  08:31AM
# 14   BTCS  Mar-16-22  09:01AM
# 15   BTCS  Mar-14-22  09:01AM
# 16   BTCS  Mar-09-22  08:31AM
# 17   BTCS  Mar-02-22  08:31AM
# 18   BTCS  Mar-01-22  09:00AM
# 19   BTCS  Feb-22-22  08:31AM
# 20   BTCS  Feb-16-22  09:00AM
# 21   BTCS  Feb-14-22  09:00AM
# 22   BTCS  Jan-24-22  08:00AM
# 23   BTCS  Jan-21-22  07:32AM
# 24   BTCS  Jan-13-22  12:09PM
# 25   BTCS  Jan-13-22  09:37AM
# 26   BTCS  Jan-13-22  08:31AM
# 27   BTCS  Jan-13-22  07:35AM
# 28   BTCS  Jan-11-22  04:36PM
# 29   BTCS  Jan-07-22  01:20PM
# 30   BTCS  Jan-06-22  02:43PM
# 31   BTCS  Jan-05-22  05:26PM
# 32   BTCS  Jan-05-22  10:25AM
# 33   BTCS  Jan-05-22  08:47AM
# 34   BTCS  Jan-05-22  08:31AM
# 35   BTCS  Dec-01-21  08:15AM
# 36   BTCS  Nov-15-21  08:13AM
# 37   BTCS  Nov-10-21  09:00AM
# 38   BTCS  Nov-02-21  09:30AM
# 39   BTCS  Oct-19-21  08:01AM
# 40   BTCS  Oct-06-21  07:31AM
# 41   BTCS  Sep-27-21  09:21AM
# 42   BTCS  Sep-17-21  08:31AM
# 43   BTCS  Sep-13-21  08:31AM
# 44   BTCS  Sep-09-21  08:45AM
# 45   BTCS  Aug-27-21  09:20AM
# 46   BTCS  Aug-17-21  08:31AM
# 47   BTCS  Aug-11-21  08:31AM
# 48   BTCS  Aug-09-21  08:31AM
# 49   BTCS  Jun-29-21  08:37AM
# 50   BTCS  Jun-28-21  08:47AM
# 51   BTCS  Jun-15-21  09:50AM
#
#                                                 title
# 0   BTCS Inc. and Force Family Office to Host a Cl...
# 1                        BTCS Reports Q2 2022 Results
# 2   BTCS Inc. Interview to Air on Bloomberg U.S. o...
# 3   BTCS Inc. will participate in the Barrons virt...
# 4   BTCS Inc. and Force Family Office to Host a Fi...
# 5   BTCS Announces Appointment of Skilled Industry...
# 6   Is BTCS (NASDAQ:BTCS) In A Good Position To De...
# 7   BTCS to Present at H. C. Wainwright Global Inv...
# 8   BTCS Inc. and Force Family Office to Host Cryp...
# 9   BTCS Shares Gain on Q1 Revenue Growth; Becomes...
# 10                       BTCS Reports Q1 2022 Results
# 11  BTCS Adds Axie Infinity to its Blockchain Infr...
# 12  BTCS Adds Kava to its Blockchain Infrastructur...
# 13  BTCS Adds Polygon to its Blockchain Infrastruc...
# 14  BTCS to Present at Ladenburg Thalmann Virtual ...
# 15                       BTCS Reports Q4 2021 Results
# 16  BTCS Adds Terra to its Growing Blockchain Infr...
# 17  BTCS Set to Offer a Dividend Payable in Bitcoi...
# 18  BTCS Adds Polkadot to its Growing Blockchain I...
# 19  BTCS Prepares for Accelerated Growth with Appo...
# 20     Solana Added to BTCS Blockchain Infrastructure
# 21  BTCS to Present at Aegis Virtual Conference on...
# 22  BTCS Adds Kusama to its Blockchain Infrastruct...
# 23  Todays Biggest Pre-Market Stock Movers: 10 Top...
# 24  BTCS Stock Alert: Why Is the Bividend Issuer S...
# 25  Blockchain firm BTCS soars on retail rush for ...
# 26  BTCS Adds Algorand to its Blockchain Infrastru...
# 27  Todays Biggest Pre-Market Stock Movers: 10 Top...
# 28  Bitcoins Tailwinds Relate to Increasing Instit...
# 29  Bitcoin Dividend News Thrusts BTCS Stock Into ...
# 30  The Bividend: Whats Up With BTCSs Bitcoin Divi...
# 31      Why Bitcoin And Friends Could Rise In January
# 32  Nasdaq-Listed Firm Says It Will Offer the Firs...
# 33  BTCS stock bounces off 1-year low after plan t...
# 34  BTCS First-ever Nasdaq-listed Company to Offer...
# 35  BTCS Strengthens Leadership, Appointing Former...
# 36  With Convertible Note Retirement, BTCS Now Deb...
# 37             BTCS Reports Q3 2021 Financial Results
# 38  BTCS Enhances Website to Better Articulate Bus...
# 39  Cosmos Now Supported By BTCS Blockchain Infras...
# 40  BTCS Digital Asset Analytics Platform In Beta ...
# 41  BTCS Retires Convertible Note Early, Eliminate...
# 42  BTCSs Expanding Blockchain Infrastructure Oper...
# 43                 BTCS to Commence Trading on Nasdaq
# 44  BTCS to Present at H.C. Wainwright 23rd Annual...
# 45  BTCS to Present at Benzinga Crypto Fest on Sep...
# 46  BTCS Announces Reverse Stock Split in Preparat...
# 47  BTCS Adds Tezos Staking to its Blockchain Infr...
# 48                       BTCS Provides Q2 2021 Update
# 49  BTCS CEO to Present at XCELLR8 RIA & WealthTec...
# 50  BTCS Appoints Veteran Finance Executive Andrew...
# 51  BTCS Grows Blockchain Infrastructure Solutions...
